# %%
import os 
import re
import json 
import pandas as pd

from datetime import datetime

# %%
data = []

# %%
dir = "data/not_music_related/"
ignore_files = [".ipynb_checkpoints", "geocov19_300000_s_loc.ndjson"] # ignore these files in the iteration 

for file in os.listdir(dir): #read all the files in the directory
    if file not in ignore_files: #ignore the two files from above
        with open(dir + file) as f: #open each file
            lines = f.readlines() #read all the lines in the file
            
            for line in lines: #looping through the tweets in each file
                tweet = json.loads(line.strip()) #tweet now contains the atributes of the line (tweet) we're looping through 
                
                if not tweet["text"].startswith("RT @"): #excluding RT's
                    tweet_data = {} #saving the coloumns we want from non-RT tweets
                    tweet_data["id"] = tweet["id"] #tweet ID
                    tweet_data["user_id"] = tweet["from_user_id"] #user ID
                         
                    date = datetime.strptime(tweet["created_at"], "%a %b %d %H:%M:%S %z %Y") #re-formatting date
                    tweet_data["date"] = date.date() #date
                    
                    url = re.findall("https:\/\/t.co\/[a-zA-Z0-9]{10}", tweet["text"])
                    if len(url) > 0:
                        tweet_data["link"] = url[0] #link from tweets
                    else : 
                        tweet_data["link"] = ""

                    tweet_data["texts"] = re.sub("https:\/\/t.co\/[a-zA-Z0-9]{10}", "", tweet["text"]) #text + removing the link
                    
                    tweet_data["country"] = tweet["user_location"]["country_code"] #country
                    if "state" in tweet["user_location"].keys(): #some tweets don't have states, but if they do we want it
                        tweet_data["state"] = tweet["user_location"]["state"] #state
                    else: 
                        tweet_data["state"] = "" #otherwise they are empty 
               
                    data.append(tweet_data) #putting it all together
# Out:
# geocov19_20400000_s_loc.ndjson
# geocov19_15300000_s_loc.ndjson
# geocov19_1000000_s_loc.ndjson
# geocov19_18300000_s_loc.ndjson
# geocov19_7600000_s_loc.ndjson
# geocov19_3800000_s_loc.ndjson
# geocov19_13500000_s_loc.ndjson
# geocov19_12900000_s_loc.ndjson
# geocov19_16700000_s_loc.ndjson
# geocov19_2400000_s_loc.ndjson
# geocov19_4200000_s_loc.ndjson
# geocov19_21800000_s_loc.ndjson
# geocov19_9200000_s_loc.ndjson
# geocov19_10100000_s_loc.ndjson
# geocov19_18600000_s_loc.ndjson
# geocov19_1500000_s_loc.ndjson
# geocov19_20100000_s_loc.ndjson
# geocov19_11800000_s_loc.ndjson
# geocov19_15600000_s_loc.ndjson
# geocov19_13000000_s_loc.ndjson
# geocov19_7300000_s_loc.ndjson
# geocov19_2100000_s_loc.ndjson
# geocov19_16200000_s_loc.ndjson
# geocov19_10400000_s_loc.ndjson
# geocov19_9700000_s_loc.ndjson
# geocov19_4700000_s_loc.ndjson
# geocov19_20500000_s_loc.ndjson
# geocov19_15200000_s_loc.ndjson
# geocov19_18200000_s_loc.ndjson
# geocov19_1100000_s_loc.ndjson
# geocov19_3900000_s_loc.ndjson
# geocov19_7700000_s_loc.ndjson
# geocov19_13400000_s_loc.ndjson
# geocov19_16600000_s_loc.ndjson
# geocov19_12800000_s_loc.ndjson
# geocov19_2500000_s_loc.ndjson
# geocov19_4300000_s_loc.ndjson
# geocov19_10000000_s_loc.ndjson
# geocov19_9300000_s_loc.ndjson
# geocov19_1400000_s_loc.ndjson
# geocov19_18700000_s_loc.ndjson
# geocov19_20000000_s_loc.ndjson
# geocov19_15700000_s_loc.ndjson
# geocov19_11900000_s_loc.ndjson
# geocov19_13100000_s_loc.ndjson
# geocov19_7200000_s_loc.ndjson
# geocov19_2000000_s_loc.ndjson
# geocov19_16300000_s_loc.ndjson
# geocov19_9600000_s_loc.ndjson
# geocov19_10500000_s_loc.ndjson
# geocov19_4600000_s_loc.ndjson
# geocov19_15100000_s_loc.ndjson
# geocov19_20600000_s_loc.ndjson
# geocov19_18100000_s_loc.ndjson
# geocov19_1200000_s_loc.ndjson
# geocov19_7400000_s_loc.ndjson
# geocov19_17900000_s_loc.ndjson
# geocov19_13700000_s_loc.ndjson
# geocov19_16500000_s_loc.ndjson
# geocov19_2600000_s_loc.ndjson
# geocov19_6800000_s_loc.ndjson
# geocov19_4000000_s_loc.ndjson
# geocov19_10300000_s_loc.ndjson
# geocov19_9000000_s_loc.ndjson
# geocov19_1700000_s_loc.ndjson
# geocov19_18400000_s_loc.ndjson
# geocov19_5900000_s_loc.ndjson
# geocov19_15400000_s_loc.ndjson
# geocov19_8900000_s_loc.ndjson
# geocov19_20300000_s_loc.ndjson
# geocov19_13200000_s_loc.ndjson
# geocov19_800000_s_loc.ndjson
# geocov19_7100000_s_loc.ndjson
# geocov19_2300000_s_loc.ndjson
# geocov19_16000000_s_loc.ndjson
# geocov19_9500000_s_loc.ndjson
# geocov19_14800000_s_loc.ndjson
# geocov19_10600000_s_loc.ndjson
# geocov19_4500000_s_loc.ndjson
# geocov19_19800000_s_loc.ndjson
# geocov19_15000000_s_loc.ndjson
# geocov19_20700000_s_loc.ndjson
# geocov19_1300000_s_loc.ndjson
# geocov19_18000000_s_loc.ndjson
# geocov19_7500000_s_loc.ndjson
# geocov19_13600000_s_loc.ndjson
# geocov19_17800000_s_loc.ndjson
# geocov19_16400000_s_loc.ndjson
# geocov19_6900000_s_loc.ndjson
# geocov19_2700000_s_loc.ndjson
# geocov19_4100000_s_loc.ndjson
# geocov19_9100000_s_loc.ndjson
# geocov19_10200000_s_loc.ndjson
# geocov19_5800000_s_loc.ndjson
# geocov19_18500000_s_loc.ndjson
# geocov19_1600000_s_loc.ndjson
# geocov19_8800000_s_loc.ndjson
# geocov19_15500000_s_loc.ndjson
# geocov19_20200000_s_loc.ndjson
# geocov19_13300000_s_loc.ndjson
# geocov19_900000_s_loc.ndjson
# geocov19_7000000_s_loc.ndjson
# geocov19_2200000_s_loc.ndjson
# geocov19_16100000_s_loc.ndjson
# geocov19_10700000_s_loc.ndjson
# geocov19_14900000_s_loc.ndjson
# geocov19_9400000_s_loc.ndjson
# geocov19_19900000_s_loc.ndjson
# geocov19_4400000_s_loc.ndjson
# geocov19_17400000_s_loc.ndjson
# geocov19_3700000_s_loc.ndjson
# geocov19_7900000_s_loc.ndjson
# geocov19_5100000_s_loc.ndjson
# geocov19_11200000_s_loc.ndjson
# geocov19_8100000_s_loc.ndjson
# geocov19_21700000_s_loc.ndjson
# geocov19_14000000_s_loc.ndjson
# geocov19_19000000_s_loc.ndjson
# geocov19_6500000_s_loc.ndjson
# geocov19_16800000_s_loc.ndjson
# geocov19_12600000_s_loc.ndjson
# geocov19_3200000_s_loc.ndjson
# geocov19_500000_s_loc.ndjson
# geocov19_17100000_s_loc.ndjson
# geocov19_8400000_s_loc.ndjson
# geocov19_15900000_s_loc.ndjson
# geocov19_11700000_s_loc.ndjson
# geocov19_5400000_s_loc.ndjson
# geocov19_18900000_s_loc.ndjson
# geocov19_19500000_s_loc.ndjson
# geocov19_4800000_s_loc.ndjson
# geocov19_21200000_s_loc.ndjson
# geocov19_14500000_s_loc.ndjson
# geocov19_9800000_s_loc.ndjson
# geocov19_12300000_s_loc.ndjson
# geocov19_6000000_s_loc.ndjson
# geocov19_100000_s_loc.ndjson
# geocov19_17500000_s_loc.ndjson
# geocov19_7800000_s_loc.ndjson
# geocov19_3600000_s_loc.ndjson
# geocov19_5000000_s_loc.ndjson
# geocov19_8000000_s_loc.ndjson
# geocov19_11300000_s_loc.ndjson
# geocov19_21600000_s_loc.ndjson
# geocov19_14100000_s_loc.ndjson
# geocov19_19100000_s_loc.ndjson
# geocov19_6400000_s_loc.ndjson
# geocov19_12700000_s_loc.ndjson
# geocov19_16900000_s_loc.ndjson
# geocov19_3300000_s_loc.ndjson
# geocov19_400000_s_loc.ndjson
# geocov19_17000000_s_loc.ndjson
# geocov19_11600000_s_loc.ndjson
# geocov19_15800000_s_loc.ndjson
# geocov19_8500000_s_loc.ndjson
# geocov19_18800000_s_loc.ndjson
# geocov19_5500000_s_loc.ndjson
# geocov19_4900000_s_loc.ndjson
# geocov19_19400000_s_loc.ndjson
# geocov19_21300000_s_loc.ndjson
# geocov19_9900000_s_loc.ndjson
# geocov19_14400000_s_loc.ndjson
# geocov19_12200000_s_loc.ndjson
# geocov19_6100000_s_loc.ndjson
# geocov19_13800000_s_loc.ndjson
# geocov19_17600000_s_loc.ndjson
# geocov19_200000_s_loc.ndjson
# .ipynb_checkpoints
# geocov19_3500000_s_loc.ndjson
# geocov19_5300000_s_loc.ndjson
# geocov19_8300000_s_loc.ndjson
# geocov19_11000000_s_loc.ndjson
# geocov19_20900000_s_loc.ndjson
# geocov19_14200000_s_loc.ndjson
# geocov19_21500000_s_loc.ndjson
# geocov19_19200000_s_loc.ndjson
# geocov19_6700000_s_loc.ndjson
# geocov19_2900000_s_loc.ndjson
# geocov19_12400000_s_loc.ndjson
# geocov19_3000000_s_loc.ndjson
# geocov19_17300000_s_loc.ndjson
# geocov19_700000_s_loc.ndjson
# geocov19_11500000_s_loc.ndjson
# geocov19_8600000_s_loc.ndjson
# geocov19_5600000_s_loc.ndjson
# geocov19_1800000_s_loc.ndjson
# geocov19_19700000_s_loc.ndjson
# geocov19_10900000_s_loc.ndjson
# geocov19_14700000_s_loc.ndjson
# geocov19_21000000_s_loc.ndjson
# geocov19_12100000_s_loc.ndjson
# geocov19_6200000_s_loc.ndjson
# geocov19_17700000_s_loc.ndjson
# geocov19_13900000_s_loc.ndjson
# geocov19_300000_s_loc.ndjson
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/dr/h0gdz53n5gvc69l85jr0mdcc0000gn/T/ipykernel_77886/1153410556.py in <module>
#       9
#      10             for line in lines: #looping through the tweets in each file
# ---> 11                 tweet = json.loads(line.strip()) #tweet now contains the atributes of the line (tweet) we're looping through
#      12
#      13                 if not tweet["text"].startswith("RT @"): #excluding RT's
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 1 column 530 (char 529)

# %%
df = pd.DataFrame(data=data) #making it a dataframe

# %%
df.to_csv("test2.csv", index=False) #saving as a csv-file
